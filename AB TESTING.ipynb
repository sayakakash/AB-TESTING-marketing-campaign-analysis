# %%
import pandas as pd
A_B_testing_control=pd.read_csv('D:\\data ANALYTICS AND SCIENCE\\COACH X ASSIGN\\DATA\\A and B_Testing\\control_group.csv')
A_B_testing_control
# Out:
#        Campaign Name        Date  Spend [USD]   of Impressions     Reach  \
# 0   Control Campaign   1.08.2019         2280          82702.0   56930.0
# 1   Control Campaign   2.08.2019         1757         121040.0  102513.0
# 2   Control Campaign   3.08.2019         2343         131711.0  110862.0
# 3   Control Campaign   4.08.2019         1940          72878.0   61235.0
# 4   Control Campaign   5.08.2019         1835              NaN       NaN
# 5   Control Campaign   6.08.2019         3083         109076.0   87998.0
# 6   Control Campaign   7.08.2019         2544         142123.0  127852.0
# 7   Control Campaign   8.08.2019         1900          90939.0   65217.0
# 8   Control Campaign   9.08.2019         2813         121332.0   94896.0
# 9   Control Campaign  10.08.2019         2149         117624.0   91257.0
# 10  Control Campaign  11.08.2019         2490         115247.0   95843.0
# 11  Control Campaign  12.08.2019         2319         116639.0  100189.0
# ...

# %%
A_B_testing_test=pd.read_csv('D:\\data ANALYTICS AND SCIENCE\\COACH X ASSIGN\\DATA\\A and B_Testing\\test_group.csv')
A_B_testing_test
# Out:
#     Campaign Name        Date  Spend [USD]  of Impressions   Reach  \
# 0   Test Campaign   1.08.2019         3008           39550   35820
# 1   Test Campaign   2.08.2019         2542          100719   91236
# 2   Test Campaign   3.08.2019         2365           70263   45198
# 3   Test Campaign   4.08.2019         2710           78451   25937
# 4   Test Campaign   5.08.2019         2297          114295   95138
# 5   Test Campaign   6.08.2019         2458           42684   31489
# 6   Test Campaign   7.08.2019         2838           53986   42148
# 7   Test Campaign   8.08.2019         2916           33669   20149
# 8   Test Campaign   9.08.2019         2652           45511   31598
# 9   Test Campaign  10.08.2019         2790           95054   79632
# 10  Test Campaign  11.08.2019         2420           83633   71286
# 11  Test Campaign  12.08.2019         2831          124591   10598
# 12  Test Campaign  13.08.2019         1972           65827   49531
# ...

# %% [markdown]
# Campaign Name: The name of the campaign (either "Control Campaign" or "Test Campaign").
#
# Date: The date of the campaign performance.
#
# Spend [USD]: The amount of money spent on the campaign in USD.
#
# Impressions: The number of times the campaign was displayed to users.
#
# Reach: The number of unique users reached by the campaign.
#
# Website Clicks: The number of clicks on the campaign leading to the website.
#
# Searches: The number of searches made on the website related to the campaign.
#
# View Content: The number of times the content related to the campaign was viewed.
#
# Add to Cart: The number of times a product was added to the cart.
#
# Purchase: The number of purchases made.

# %%
# Show FIRST  5 rows of control campaign dataset
A_B_testing_control.head(5)
# Out:
#       Campaign Name       Date  Spend [USD]   of Impressions     Reach  \
# 0  Control Campaign  1.08.2019         2280          82702.0   56930.0
# 1  Control Campaign  2.08.2019         1757         121040.0  102513.0
# 2  Control Campaign  3.08.2019         2343         131711.0  110862.0
# 3  Control Campaign  4.08.2019         1940          72878.0   61235.0
# 4  Control Campaign  5.08.2019         1835              NaN       NaN
#
#     of Website Clicks   of Searches   of View Content   of Add to Cart  \
# 0              7016.0        2290.0            2159.0           1819.0
# 1              8110.0        2033.0            1841.0           1219.0
# 2              6508.0        1737.0            1549.0           1134.0
# 3              3065.0        1042.0             982.0           1183.0
# 4                 NaN           NaN               NaN              NaN
#
#    of Purchase
# 0        618.0
# 1        511.0
# 2        372.0
# 3        340.0
# 4          NaN

# %%
# Show LAST 5 rows of control campaign dataset
A_B_testing_control.tail(5)
# Out:
#        Campaign Name        Date  Spend [USD]   of Impressions     Reach  \
# 25  Control Campaign  26.08.2019         2233         124897.0   98432.0
# 26  Control Campaign  27.08.2019         2061         104678.0   91579.0
# 27  Control Campaign  28.08.2019         2421         141654.0  125874.0
# 28  Control Campaign  29.08.2019         2375          92029.0   74192.0
# 29  Control Campaign  30.08.2019         2324         111306.0   88632.0
#
#      of Website Clicks   of Searches   of View Content   of Add to Cart  \
# 25              5435.0        2847.0            2421.0           1448.0
# 26              4941.0        3549.0            3249.0            980.0
# 27              6287.0        1672.0            1589.0           1711.0
# 28              8127.0        4891.0            4219.0           1486.0
# 29              4658.0        1615.0            1249.0            442.0
#
#     of Purchase
# 25        251.0
# 26        605.0
# 27        643.0
# 28        334.0
# ...

# %%
# Check for null values in control campaign dataset
A_B_testing_control.isnull().sum()
# Out:
# Campaign Name         0
# Date                  0
# Spend [USD]           0
#  of Impressions       1
# Reach                 1
#  of Website Clicks    1
#  of Searches          1
#  of View Content      1
#  of Add to Cart       1
# of Purchase           1
# dtype: int64

# %%
A_B_testing_control[' of Impressions'].fillna(A_B_testing_control[' of Impressions'].mean(), inplace=True)
A_B_testing_control['Reach'].fillna(A_B_testing_control['Reach'].mean(), inplace=True)
A_B_testing_control[' of Website Clicks'].fillna(A_B_testing_control[' of Website Clicks'].mean(), inplace=True)
A_B_testing_control[' of Searches'].fillna(A_B_testing_control[' of Searches'].mean(), inplace=True)
A_B_testing_control[' of View Content'].fillna(A_B_testing_control[' of View Content'].mean(), inplace=True)
A_B_testing_control[' of Add to Cart'].fillna(A_B_testing_control[' of Add to Cart'].mean(), inplace=True)
A_B_testing_control['of Purchase'].fillna(A_B_testing_control['of Purchase'].mean(), inplace=True)

# %%
# Check for null values in control campaign dataset
A_B_testing_control.isnull().sum()
# Out:
# Campaign Name         0
# Date                  0
# Spend [USD]           0
#  of Impressions       0
# Reach                 0
#  of Website Clicks    0
#  of Searches          0
#  of View Content      0
#  of Add to Cart       0
# of Purchase           0
# dtype: int64

# %%
# Check for null values in test campaign dataset
A_B_testing_test.isnull().sum()
# Out:
# Campaign Name         0
# Date                  0
# Spend [USD]           0
# of Impressions        0
# Reach                 0
#  of Website Clicks    0
#  of Searches          0
# of View Content       0
#  of Add to Cart       0
#  of Purchase          0
# dtype: int64

# %%
column_names = A_B_testing_control.columns
column_names
# Out:
# Index(['Campaign Name', 'Date', 'Spend [USD]', ' of Impressions', 'Reach',
#        ' of Website Clicks', ' of Searches', ' of View Content',
#        ' of Add to Cart', 'of Purchase'],
#       dtype='object')

# %%
column_names_train= A_B_testing_test.columns
column_names_train
# Out:
# Index(['Campaign Name', 'Date', 'Spend [USD]', 'of Impressions', 'Reach',
#        ' of Website Clicks', ' of Searches', 'of View Content',
#        ' of Add to Cart', ' of Purchase'],
#       dtype='object')

# %%
A_B_testing_control.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Campaign Name       30 non-null     object
#  1   Date                30 non-null     object
#  2   Spend [USD]         30 non-null     int64
#  3    of Impressions     30 non-null     float64
#  4   Reach               30 non-null     float64
#  5    of Website Clicks  30 non-null     float64
#  6    of Searches        30 non-null     float64
#  7    of View Content    30 non-null     float64
#  8    of Add to Cart     30 non-null     float64
#  9   of Purchase         30 non-null     float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.5+ KB

# %%
A_B_testing_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Campaign Name       30 non-null     object
#  1   Date                30 non-null     object
#  2   Spend [USD]         30 non-null     int64
#  3   of Impressions      30 non-null     int64
#  4   Reach               30 non-null     int64
#  5    of Website Clicks  30 non-null     int64
#  6    of Searches        30 non-null     int64
#  7   of View Content     30 non-null     int64
#  8    of Add to Cart     30 non-null     int64
#  9    of Purchase        30 non-null     int64
# dtypes: int64(8), object(2)
# memory usage: 2.5+ KB

# %%
A_B_testing_test['of Impressions'] = A_B_testing_test['of Impressions'].astype(float)

# %%
A_B_testing_test['Reach'] = A_B_testing_test['Reach'].astype(float)

# %%
A_B_testing_test['of View Content'] = A_B_testing_test['of View Content'].astype(float)

# %%
A_B_testing_test['Spend [USD]'] = A_B_testing_test['Spend [USD]'].astype(int)

# %%
A_B_testing_test[' of Website Clicks'] = A_B_testing_test[' of Website Clicks'].astype(float)

# %%
A_B_testing_test[' of Purchase'] = A_B_testing_test[' of Purchase'].astype(float)

# %%
A_B_testing_test[' of Add to Cart'] = A_B_testing_test[' of Add to Cart'].astype(float)

# %%
A_B_testing_test[' of Searches'] = A_B_testing_test[' of Searches'].astype(float)

# %%
A_B_testing_control.columns = A_B_testing_control.columns.str.strip()
A_B_testing_test.columns = A_B_testing_test.columns.str.strip()

merged_df_1 = pd.merge(A_B_testing_control, A_B_testing_test, on=['Campaign Name', 'Date', 'Spend [USD]', 
                                                                  'of Impressions', 'Reach', 'of Website Clicks', 
                                                                  'of Searches', 'of View Content', 'of Add to Cart',
                                                                  'of Purchase'], how='outer')

merged_df_1
# Out:
#        Campaign Name        Date  Spend [USD]  of Impressions          Reach  \
# 0   Control Campaign   1.08.2019         2280    82702.000000   56930.000000
# 1   Control Campaign   2.08.2019         1757   121040.000000  102513.000000
# 2   Control Campaign   3.08.2019         2343   131711.000000  110862.000000
# 3   Control Campaign   4.08.2019         1940    72878.000000   61235.000000
# 4   Control Campaign   5.08.2019         1835   109559.758621   88844.931034
# 5   Control Campaign   6.08.2019         3083   109076.000000   87998.000000
# 6   Control Campaign   7.08.2019         2544   142123.000000  127852.000000
# 7   Control Campaign   8.08.2019         1900    90939.000000   65217.000000
# 8   Control Campaign   9.08.2019         2813   121332.000000   94896.000000
# 9   Control Campaign  10.08.2019         2149   117624.000000   91257.000000
# 10  Control Campaign  11.08.2019         2490   115247.000000   95843.000000
# ...

# %% [markdown]
# ### Z TEST ###
#
# Z-test to determine if the sales (specified as 2500) in the merged_df_1 dataset is significantly different from the mean of the combined data.

# %%
import numpy as np
import numpy as np
from scipy import stats
import pandas as pd

combined_data = merged_df_1['Spend [USD]'].values

# Specify the value for the average sales
specified_value = 2500

# Calculate the mean and standard deviation of the combined dataset
mean = np.mean(combined_data)
std_dev = np.std(combined_data)

# Calculate the Z-score
n = len(combined_data)
z_score = (mean - specified_value) / (std_dev / np.sqrt(n))
z_score
# Define the significance level
significance_level = 0.05

# Calculate the critical Z-value
critical_value = stats.norm.ppf(1 - significance_level / 2)

# Compare the Z-score with the critical value
if abs(z_score) > critical_value:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# Fail to reject the null hypothesis

# %% [markdown]
# ### ANOVA ANALYSIS ###

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Create a sample DataFrame
data = merged_df_1[['Campaign Name', 'Spend [USD]']]

# Rename the columns to remove spaces
data = data.rename(columns={'Spend [USD]': 'Spend_USD', 'Campaign Name': 'Campaign_Name'})

# Fit the ANOVA model
model = ols('Spend_USD ~ Campaign_Name', data=data).fit()

# Perform ANOVA analysis
anova_table = sm.stats.anova_lm(model)

# Print the ANOVA table
print(anova_table)
# Out:
#                  df        sum_sq       mean_sq        F    PR(>F)
# Campaign_Name   1.0  1.131352e+06  1.131352e+06  8.82085  0.004326
# Residual       58.0  7.439013e+06  1.282588e+05      NaN       NaN

# %% [markdown]
# The F value is 8.82085. A larger F value suggests a larger difference between the means of the groups being compared.
# p-value is 0.004326, which is less than 0.05(ignificance level).
# The null hypothesis in this case state that there are no significant differences between the means of the two groups
# Control Campaign and Test Campaign
# But we see p-value is 0.004326, which is less than 0.05.Therefore null hypothesis gets rejected and alternate hypothesis gets accepted.This means that there are significant differences between the means of the groups being compared.
# If the F-value is large and the p-value is small (typically less than a predetermined significance level, such as 0.05), it indicates that there is a significant difference between the means of the two groups.
#
# The ANOVA results suggest that there are significant differences between the Control Campaign and Test Campaign groups. This implies that the campaign type has an impact on sales performance

# %% [markdown]
# ### Gaussian distribution  to check outliers ###

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
# Fit a Gaussian distribution to the "Sales USD" data
mu, sigma = stats.norm.fit(merged_df_1["Spend [USD]"])
mu, sigma

# Define a threshold for anomaly detection (e.g., 3 standard deviations from the mean)
threshold = mu - 1.5 * sigma
threshold

# Identify outliers as data points with PDF values below the threshold
outliers = merged_df_1[merged_df_1['Spend [USD]'] < threshold]
outliers
# Out:
#        Campaign Name        Date  Spend [USD]  of Impressions          Reach  \
# 1   Control Campaign   2.08.2019         1757   121040.000000  102513.000000
# 4   Control Campaign   5.08.2019         1835   109559.758621   88844.931034
# 20  Control Campaign  21.08.2019         1803    74654.000000   59873.000000
#
#     of Website Clicks  of Searches  of View Content  of Add to Cart  \
# 1         8110.000000  2033.000000      1841.000000          1219.0
# 4         5320.793103  2221.310345      1943.793103          1300.0
# 20        5691.000000  2711.000000      2496.000000          1460.0
#
#     of Purchase
# 1    511.000000
# 4    522.793103
# 20   800.000000

# %% [markdown]
# ### scatter plot for  Spend [USD]  vs of Impressions	###

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a DataFrame
data = merged_df_1

# Extract the relevant columns
impressions = data['of Impressions']
amount_spent = data['Spend [USD]']
campaign_name = data['Campaign Name']

# Filter data for Test Campaign
test_campaign_data = data[data['Campaign Name'] == 'Test Campaign']
test_impressions = test_campaign_data['of Impressions']
test_amount_spent = test_campaign_data['Spend [USD]']

# Filter data for Control Campaign
control_campaign_data = data[data['Campaign Name'] == 'Control Campaign']
control_impressions = control_campaign_data['of Impressions']
control_amount_spent = control_campaign_data['Spend [USD]']

# Create a scatter plot for Test Campaign
plt.scatter(test_impressions, test_amount_spent, label='Test Campaign')

# Create a scatter plot for Control Campaign
plt.scatter(control_impressions, control_amount_spent, label='Control Campaign')

plt.xlabel('Number of Impressions')
plt.ylabel('Amount Spent')
plt.title('Relationship between Impressions and Amount Spent')
plt.legend()  # Add legend
plt.show()

# %% [markdown]
# ### Pie chart to show number of searches performed on the website from both campaigns ###

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a DataFrame
data = merged_df_1

# Filter data for Test Campaign
test_campaign_data = data[data['Campaign Name'] == 'Test Campaign']
test_searches = test_campaign_data['of Searches'].sum()

# Filter data for Control Campaign
control_campaign_data = data[data['Campaign Name'] == 'Control Campaign']
control_searches = control_campaign_data['of Searches'].sum()

# Create a pie chart
labels = ['Test Campaign\n' + str(test_searches), 'Control Campaign\n' + str(control_searches)]
sizes = [test_searches, control_searches]
colors = ['red', 'orange']
explode = (0.1, 0)  # Explode the first slice (Test Campaign)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.title('Number of Searches by Campaign')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# ### Pie chart to show number of  clicks on the campaign leading to the website ###

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a DataFrame
data = merged_df_1

# Filter data for Test Campaign
test_campaign_data = data[data['Campaign Name'] == 'Test Campaign']
test_clicks = test_campaign_data['of Website Clicks'].sum()

# Filter data for Control Campaign
control_campaign_data = data[data['Campaign Name'] == 'Control Campaign']
control_clicks = control_campaign_data['of Website Clicks'].sum()

# Create a pie chart
labels = ['Test Campaign\n' + str(test_clicks), 'Control Campaign\n' + str(control_clicks)]
sizes = [test_clicks, control_clicks]
colors = ['green', 'orange']
explode = (0.1, 0)  # Explode the first slice (Test Campaign)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.title('Number of Website Clicks by Campaign')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# ### Pie chart to show amount of content viewed after reaching the website ###

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a DataFrame
data = merged_df_1

# Filter data for Test Campaign
test_campaign_data = data[data['Campaign Name'] == 'Test Campaign']
test_content_viewed = test_campaign_data['of View Content'].sum()

# Filter data for Control Campaign
control_campaign_data = data[data['Campaign Name'] == 'Control Campaign']
control_content_viewed = control_campaign_data['of View Content'].sum()

# Create a pie chart
labels = ['Test Campaign\n' + str(test_content_viewed), 'Control Campaign\n' + str(control_content_viewed)]
sizes = [test_content_viewed, control_content_viewed]
colors = ['pink', 'red']
explode = (0.1, 0)  # Explode the first slice (Test Campaign)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.title('Amount of Content Viewed after Website Visit by Campaign')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# ### Number of products added to the cart from both campaigns and give the amount spent on both campaigns ###

# %%
import pandas as pd

# Load the data into a DataFrame
data = merged_df_1

# Filter data for Test Campaign
test_campaign_data = data[data['Campaign Name'] == 'Test Campaign']
test_products_added = test_campaign_data['of Add to Cart'].sum()
test_amount_spent = test_campaign_data['Spend [USD]'].sum()

# Filter data for Control Campaign
control_campaign_data = data[data['Campaign Name'] == 'Control Campaign']
control_products_added = control_campaign_data['of Add to Cart'].sum()
control_amount_spent = control_campaign_data['Spend [USD]'].sum()

# Print the results
print('Number of Products Added to Cart - Test Campaign:', test_products_added)
print('Amount Spent - Test Campaign:', test_amount_spent)
print('Number of Products Added to Cart - Control Campaign:', control_products_added)
print('Amount Spent - Control Campaign:', control_amount_spent)
# Out:
# Number of Products Added to Cart - Test Campaign: 26446.0
# Amount Spent - Test Campaign: 76892
# Number of Products Added to Cart - Control Campaign: 39000.0
# Amount Spent - Control Campaign: 68653

# %% [markdown]
# **Given the purchases made by both campaigns, let’s analyze some metrics to find which ad campaign converts more.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a DataFrame
data = merged_df_1

# Filter data for Test Campaign
test_campaign_data = data[data['Campaign Name'] == 'Test Campaign']
test_clicks = test_campaign_data['of Website Clicks'].sum()
test_content_viewed = test_campaign_data['of View Content'].sum()
test_purchases = test_campaign_data['of Purchase'].sum()

# Filter data for Control Campaign
control_campaign_data = data[data['Campaign Name'] == 'Control Campaign']
control_clicks = control_campaign_data['of Website Clicks'].sum()
control_content_viewed = control_campaign_data['of View Content'].sum()
control_purchases = control_campaign_data['of Purchase'].sum()

# Create a pie chart to show the distribution of clicks, content viewed, and purchases
labels = ['Clicks', 'Content Viewed', 'Purchases']
sizes_test = [test_clicks, test_content_viewed, test_purchases]
sizes_control = [control_clicks, control_content_viewed, control_purchases]
colors = ['pink', 'yellow', 'brown']

fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Pie chart for Test Campaign
axs[0].pie(sizes_test, labels=labels, colors=colors, autopct='%1.1f%%',
           shadow=True, startangle=90)
axs[0].set_title('Test Campaign')

# Pie chart for Control Campaign
axs[1].pie(sizes_control, labels=labels, colors=colors, autopct='%1.1f%%',
           shadow=True, startangle=90)
axs[1].set_title('Control Campaign')

plt.suptitle('Distribution of Website Clicks, Content Viewed, and Purchases by Campaign')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

plt.show()

# %% [markdown]
# **For comaparing conversion rate i am taking
# conversion rates = the number of purchases /  the number content viewed.**
#
# Test Campaign=6.2/22.1=0.28
#
#
# Control Campaign =6.7/25=0.26
#
# Therefore Test Campaign has more conversion rate

# %% [markdown]
# ### Scatter plot for relationship between the amount of content viewed and the number of products added to the cart from both campaigns. ###

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a DataFrame
data = merged_df_1

# Filter data for Test Campaign
test_campaign_data = data[data['Campaign Name'] == 'Test Campaign']
test_content_viewed = test_campaign_data['of View Content']
test_products_added = test_campaign_data['of Add to Cart']

# Filter data for Control Campaign
control_campaign_data = data[data['Campaign Name'] == 'Control Campaign']
control_content_viewed = control_campaign_data['of View Content']
control_products_added = control_campaign_data['of Add to Cart']

# Create a scatter plot
plt.scatter(test_content_viewed, test_products_added, label='Test Campaign')
plt.scatter(control_content_viewed, control_products_added, label='Control Campaign')
plt.xlabel('Amount of Content Viewed')
plt.ylabel('Number of Products Added to Cart')
plt.title('Relationship between Content Viewed and Products Added to Cart')
plt.legend()
plt.show()

# %% [markdown]
# Control Campaign has more number of products adddedto cart as compared to Test Campaign

# %% [markdown]
# **Scatter Chart to show the relationship between the number of products added to the cart and the number of sales from both campaigns**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a DataFrame
data = merged_df_1

# Filter data for Test Campaign
test_campaign_data = data[data['Campaign Name'] == 'Test Campaign']
test_products_added = test_campaign_data['of Add to Cart']
test_sales = test_campaign_data['of Purchase']

# Filter data for Control Campaign
control_campaign_data = data[data['Campaign Name'] == 'Control Campaign']
control_products_added = control_campaign_data['of Add to Cart']
control_sales = control_campaign_data['of Purchase']

# Create a scatter plot
plt.scatter(test_products_added, test_sales, label='Test Campaign')
plt.scatter(control_products_added, control_sales, label='Control Campaign')
plt.xlabel('Number of Products Added to Cart')
plt.ylabel('Number of Sales')
plt.title('Relationship between Products Added to Cart and Sales')
plt.legend()
plt.show()

# %% [markdown]
# Control Campaign has more number of sales with less product added to the cart as compared to Test Campaign which has less number of sales with more numner of products added to cart
